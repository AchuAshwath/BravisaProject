# %%
import pandas as pd

csv_file = "C:\\Users\\dsram\\OneDrive\\Desktop\\Braviza\\app\\OHLCFiles\\BhavCopy_NSE_CM_0_0_0_20240711_F_0000.csv"

table = pd.read_csv(csv_file)
og_table = table

nse_changed_format_dictionary = {'TckrSymb' : 'SYMBOL', 'SctySrs': 'SERIES','OpnPric': 'OPEN', 	'HghPric' :'HIGH',	'LwPric':'LOW',	'ClsPric' :'CLOSE',	
                                'LastPric' : 'LAST', 'PrvsClsgPric' : 'PREVCLOSE','TtlTradgVol' : 'TOTTRDQTY',	'TtlTrfVal' : 'TOTTRDVAL', 'TradDt' : 'TIMESTAMP',
                                'TtlNbOfTxsExctd' : 'TOTALTRADES','ISIN':'ISIN'}

table.rename(columns = nse_changed_format_dictionary, inplace= True)
table_re = table

table_columns = ['SYMBOL', 'SERIES', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'LAST',
                'PREVCLOSE', 'TOTTRDQTY', 'TOTTRDVAL', 'TIMESTAMP', 'TOTALTRADES', 'ISIN']
csv_columns = list(table.columns.values)
columns_to_remove = [x for x in csv_columns if x not in table_columns]

table = table.drop(columns_to_remove, axis=1)
table = table[table.SERIES.isin(["EQ", "BZ", "BE", "RR", "IV"])]
table = table[['SYMBOL', 'SERIES', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'LAST',
            'PREVCLOSE', 'TOTTRDQTY', 'TOTTRDVAL', 'TIMESTAMP', 'TOTALTRADES', 'ISIN']]

table.to_csv('converted-nse-file-sample.csv')

# %%
import lib.ohlc
import pandas as pd

date_range = pd.date_range(start='2024-07-09', end='2024-07-09')

for curr_date in date_range:
    lib.ohlc.main(curr_date)
# Out:
# File Path : C:\Users\dsram\OneDrive\Desktop\Braviza\app\OHLCFiles\
#
# 		 OHLC Fetch Service Started..........
#
#
#
# NSE Fetch invoked ....
# nse file :  C:\Users\dsram\OneDrive\Desktop\Braviza\app\OHLCFiles\BhavCopy_NSE_CM_0_0_0_20240709_F_0000.csv
#           SYMBOL SERIES     OPEN     HIGH      LOW    CLOSE     LAST  \
# 0          AAVAS     EQ  1808.00  1808.00  1790.05  1800.40  1802.85
# 2          AWHCL     EQ   603.00   607.95   585.90   591.65   589.05
# 4     CONSOFINVT     EQ   199.50   199.50   194.00   194.28   194.05
# 5          VPRPL     EQ   205.30   206.50   201.02   201.64   201.25
# 6      PPLPHARMA     EQ   154.49   156.60   153.12   155.77   155.95
# ...          ...    ...      ...      ...      ...      ...      ...
# 2790      GMBREW     EQ   919.00   945.00   860.30   888.25   883.00
# 2791  GEEKAYWIRE     EQ    97.65    99.00    95.57    96.20    96.30
# 2792      KHADIM     EQ   362.50   366.25   361.35   361.75   361.40
# 2793   KIRIINDUS     EQ   365.40   365.40   353.05   355.45   354.00
# 2794  DIVOPPBEES     EQ    85.05    85.05    80.05    82.57    82.60
#
#       PREVCLOSE  TOTTRDQTY     TOTTRDVAL   TIMESTAMP  TOTALTRADES  \
# 0       1797.15     101643  1.830118e+08  2024-07-09        11755
# 2        602.70     406211  2.412904e+08  2024-07-09        16228
# 4        195.38      10599  2.065482e+06  2024-07-09          704
# 5        204.14     652175  1.325168e+08  2024-07-09        10774
# 6        154.02    1826344  2.834793e+08  2024-07-09        22841
# ...         ...        ...           ...         ...          ...
# 2790     907.30     865973  7.873393e+08  2024-07-09        27113
# 2791      96.69     344682  3.357297e+07  2024-07-09         6804
# 2792     362.50      16850  6.117927e+06  2024-07-09         1126
# 2793     363.85     348201  1.250704e+08  2024-07-09        13157
# 2794      82.55     103013  8.506551e+06  2024-07-09         1217
#
#               ISIN
# 0     INE216P01012
# 2     INE01BK01022
# 4     INE025A01027
# 5     INE0AE001013
# 6     INE0DK501011
# ...            ...
# 2790  INE075D01018
# 2791  INE669X01024
# 2792  INE834I01025
# 2793  INE415I01015
# 2794  INF204KA1MS3
#
# [2193 rows x 13 columns]
#
#
# BSE Fetch invoked ....
# bse file :  C:\Users\dsram\OneDrive\Desktop\Braviza\app\OHLCFiles\BhavCopy_BSE_CM_0_0_0_20240709_F_0000.csv
#       SC_CODE     SC_NAME SC_GROUP  SC_TYPE       OPEN       HIGH        LOW  \
# 0      500002         ABB        A      NaN    8560.05    8715.90    8554.75
# 1      500003    AEGISLOG        A      NaN     927.00     969.95     927.00
# 2      500008       ARE&M        A      NaN    1699.35    1700.95    1652.00
# 3      500009   AMBALALSA        X      NaN      55.50      62.00      54.37
# 4      500012   ANDHRAPET        X      NaN     116.30     117.50     115.05
# ...       ...         ...      ...      ...        ...        ...        ...
# 4372   975506   1250UCL29        F      NaN   99449.00   99449.00   99449.00
# 4373   975532   115ESPL25        F      NaN   99809.79   99809.79   99809.79
# 4374   975629  1425CSAI26        F      NaN  100000.00  100000.00  100000.00
# 4375   975652   1076LFL26        F      NaN   98350.46   98350.46   98350.46
# 4376   975794  1182KSPL26        F      NaN  100263.00  100263.00  100263.00
#
#           CLOSE       LAST  PREVCLOSE  NO_TRADES  NO_OF_SHRS  NET_TURNOV  \
# 0       8572.45    8591.65    8558.85        903        3824  32943771.0
# 1        932.60     932.60     925.90       1515       22814  21449476.0
# 2       1670.70    1670.70    1683.25       5027       52005  87005681.0
# 3         61.22      61.22      54.37       3952     1184890  70115624.0
# 4        115.55     115.55     115.35       1348      198554  23040591.0
# ...         ...        ...        ...        ...         ...         ...
# 4372   99449.00   99449.00   99749.00          4           6    596694.0
# 4373   99809.79   99809.79       0.00          2           2    199619.0
# 4374  100000.00  100000.00   99999.00          2          35   3500000.0
# 4375   98350.46   98350.46       0.00          2           2    196700.0
# 4376  100263.00  100263.00       0.00          1         100  10026300.0
#
#       TDCLOINDI     ISIN_CODE TRADING_DATE
# 0           NaN  INE117A01022   2024-07-09
# 1           NaN  INE208C01025   2024-07-09
# 2           NaN  INE885A01032   2024-07-09
# 3           NaN  INE432A01017   2024-07-09
# 4           NaN  INE714B01016   2024-07-09
# ...         ...           ...          ...
# 4372        NaN  INE583D08057   2024-07-09
# 4373        NaN  INE01YL07268   2024-07-09
# 4374        NaN  INE0LWH07054   2024-07-09
# 4375        NaN  INE090W07683   2024-07-09
# 4376        NaN  INE07HK07759   2024-07-09
#
# [4377 rows x 16 columns]
# initial ohlc_full :  4559
# bttlist :  1041
# initial companycode nulls in ohlc :  2707
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:425: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   table_ohlc["ISIN"].fillna(table_ohlc["ISIN_CODE"], inplace=True)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:426: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   table_ohlc["OPEN_x"].fillna(table_ohlc["OPEN_y"], inplace=True)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:427: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   table_ohlc["HIGH_x"].fillna(table_ohlc["HIGH_y"], inplace=True)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:428: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   table_ohlc["LOW_x"].fillna(table_ohlc["LOW_y"], inplace=True)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:429: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   table_ohlc["CLOSE_x"].fillna(table_ohlc["CLOSE_y"], inplace=True)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:430: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   table_ohlc["LAST_x"].fillna(table_ohlc["LAST_y"], inplace=True)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:431: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   table_ohlc["PREVCLOSE_x"].fillna(table_ohlc["PREVCLOSE_y"], inplace=True)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:432: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   table_ohlc["TIMESTAMP"].fillna(table_ohlc["TRADING_DATE"], inplace=True)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:433: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   table_ohlc["TOTTRDVAL"].fillna(table_ohlc["NET_TURNOV"], inplace=True)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:434: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   table_ohlc["TOTTRDQTY"].fillna(table_ohlc["NO_OF_SHRS"], inplace=True)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:448: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   table_ohlc["BSECode"].fillna(-1, inplace=True)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:460: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = sqlio.read_sql_query(sql_background, con=conn)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:462: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   table_ohlc["BSECode"].fillna(0, inplace=True)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:500: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   bttlist = pd.read_sql_query(btt_sql, con=conn, params=(BTT_back, BTT_next))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[   1121    2704    1596 ...     106 1549728   45195]' has dtype incompatible with int32, please explicitly cast to a compatible dtype first.
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:547: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(coco_null_ohlc_full)
# ...
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# ohlc_full :  4001
# count count replaced in backgrounndinfo :  2148
#          Company     NSECode BSECode          ISIN     Open     High      Low  \
# 0          07GPG         NaN  543079  INF204KB16R8     1.00     1.00     0.82
# 75        1STCUS         NaN  511122  INE609B01018   113.15   113.15   113.15
# 76     20MICRONS   20MICRONS  533022  INE144J01027   224.99   236.00   224.99
# 77    21STCENMGM  21STCENMGM  526921  INE253B01015    76.44    76.44    76.44
# 78        360ONE      360ONE  542772  INE466L01038   984.00  1011.80   971.10
# ...          ...         ...     ...           ...      ...      ...      ...
# 4554       ZUARI       ZUARI  534742  INE840M01016   237.09   245.00   232.50
# 4555    ZUARIIND    ZUARIIND  500780  INE217A01012   414.95   423.00   412.60
# 4556    ZWELCAST         NaN  504988  INE380G01015  1470.00  1499.95  1457.00
# 4557   ZYDUSLIFE   ZYDUSLIFE  532321  INE010B01027  1159.00  1177.00  1156.20
# 4558   ZYDUSWELL   ZYDUSWELL  531335  INE768C01010  2069.95  2119.90  2050.00
#
#         Close        Date         Value   Volume  CompanyCode      ISINCode
# 0        0.84  2024-07-09  9.700000e+02     1121          NaN           NaN
# 75     113.15  2024-07-09  1.244000e+03       11   14010060.0  INE609B01018
# 76     229.02  2024-07-09  1.143233e+08   496554   15110088.0  INE144J01027
# 77      76.44  2024-07-09  4.380776e+05     5731   14010024.0  INE253B01015
# 78     996.85  2024-07-09  7.366614e+08   741786   14010688.0  INE466L01038
# ...       ...         ...           ...      ...          ...           ...
# 4554   234.01  2024-07-09  2.378598e+08   995260   12324327.5  INE840M01016
# 4555   415.35  2024-07-09  8.752165e+07   209637   12100011.0  INE217A01012
# 4556  1459.30  2024-07-09  1.556460e+05      106   15520010.0  INE380G01015
# 4557  1165.45  2024-07-09  1.808497e+09  1549728   12540403.0  INE010B01027
# 4558  2103.35  2024-07-09  9.453983e+07    45195   11060041.0  INE768C01010
#
# [4001 rows x 13 columns]
#
# 		 OHLC Fetch Completed.
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:574: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   background_info = pd.read_sql_query(background_info_sql, con=conn, params=(nsecode, bsecode, isin))
# c:\Users\dsram\OneDrive\Desktop\Braviza\app\lib\ohlc.py:589: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   ohlc_full.update(null_btt_ohlc)
